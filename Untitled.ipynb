# %%
a=int(input("enter number 1:"))
b=int(input("enter number 2:"))
print(" 1.addition \n 2.substraction \n 3.multiplication \n 4.division")
ch=int(input("enter your choice:"))
if ch==1:
    print("ans=",a+b)
elif ch==2:
    print("ans=",a-b)
elif ch==3:
    print("ans=",a*b)
elif ch==4:
    print("ans=",a/b)
else:
    print("invalid choice!!")
# Out:
# enter number 1:1
# enter number 2:3
#  1.addition
#  2.substraction
#  3.multiplication
#  4.division
# enter your choice:1
# ans= 4

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
print("AND =",a and b)
print("OR  =",a or b)
print("NOT =", not a)
print("a=b =",a==b)
print("a>b =",a>b)
print("a<b =",a<b)
print("a>=b=",a>=b)
print("a<=b=",a<=b)
# Out:
# enter the first number:2
# enter the second number:1
# AND = 1
# OR  = 2
# NOT = False
# a=b = False
# a>b = True
# a<b = False
# a>=b= True
# a<=b= False

# %%
a={"name":"shahale","place":"koduvally","age":23}
b={"phonr":9633622384,"pin":673572,"education":"mca"}
a.update(b)
print(a)
# Out:
# {'name': 'shahale', 'place': 'koduvally', 'age': 23, 'phonr': 9633622384, 'pin': 673572, 'education': 'mca'}

# %%
a=int(input("enter number 1:"))
b=int(input("enter number 2:"))
c=int(input("enter number 3:"))
if a>b and b>c:
    print("gratest=",a)
elif b>c:
    print("greatest=",b)
else:
    print("greatest=",c)
# Out:
# enter number 1:2
# enter number 2:3
# enter number 3:1
# greatest= 3

# %%
a=[1,2,3,4,5,6]
b=[10,11]
a.insert(2,8)
a.pop(2)
a.append(7)
a.remove(2)
b=a.copy()


print(a)
print(b)
# Out:
# [1, 3, 4, 5, 6, 7]
# [1, 3, 4, 5, 6, 7]
